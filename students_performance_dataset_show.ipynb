# %% [markdown]
# <a href="https://colab.research.google.com/github/TasnimJahan/REclsTsnm_Practice_Asgnmnt/blob/main/students_performance_dataset_show.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# Practice: Students Performance Dataset
# ============================================================

import numpy as np
import pandas as pd


from google.colab import drive
drive.mount('/content/drive')

import warnings
warnings.filterwarnings('ignore')





# Q1. Display the first 5 rows of the dataset, then print its shape

# Q2. Print the average (mean) math score, reading score and writing score
# Out:
# Mounted at /content/drive

# %%
# Load the dataset
file_path = '/content/drive/MyDrive/Datasets/SkillMorph/StudentsPerformance.csv'
df = pd.read_csv(file_path)  # No header in raw CSV
print("Dataset loaded successfully. Shape:", df.shape)
# Out:
# Dataset loaded successfully. Shape: (1000, 8)

# %%
# Q1. Display the first 5 rows of the dataset, then print its shape

print(df.head())
print("Shape of this dataset: ", df.shape)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# Shape of this dataset:  (1000, 8)

# %%
# Q2. Print the average (mean) math score, reading score and writing score

# print(df.info())
print("Overall description:\n",df.describe())
# print("\n\nThe average (mean) math score, reading score and writing score\n", df.mean())

print(df[['math score', 'reading score', 'writing score']].mean())

print(df.mean(numeric_only=True))   # shb numerial value er col gular avg
# Out:
# Overall description:
#         math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64
